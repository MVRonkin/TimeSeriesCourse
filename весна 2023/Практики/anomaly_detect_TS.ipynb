# %%
import numpy as np
import pandas as pd

import matplotlib.pyplot as plt
from datetime import datetime
import seaborn as sns
sns.set(style="whitegrid")

import warnings
warnings.filterwarnings('ignore')

RANDOM_SEED = np.random.seed(0)

# %% [markdown]
# Данные: набор востребованности такси в городе Нью Йорк с шагом в 1 час.

# %%
import pandas as pd
data = pd.read_csv('https://raw.githubusercontent.com/numenta/NAB/master/data/realKnownCause/nyc_taxi.csv')
data['timestamp'] = pd.to_datetime(data['timestamp'])
data = data.set_index(['timestamp']).asfreq('h')
data.head()
# Out:
#                      value
# timestamp
# 2014-07-01 00:00:00  10844
# 2014-07-01 01:00:00   6210
# 2014-07-01 02:00:00   3820
# 2014-07-01 03:00:00   2369
# 2014-07-01 04:00:00   2221

# %%
y = data.value.values.reshape(-1, 1)

# %%
plt.plot(data.index, y)

# %% [markdown]
# Данные во временных рядах можно рассматривать как в чистом виде, так и преобразовать.
#
# Попробуем скользящее средние и скользящие СКО

# %%
plt.rc('figure',figsize=(12,6))
plt.rc('font',size=15)
# create moving-averages
data['value'].rolling(24).mean().plot()
data['value'].rolling(24).std().plot()
data['value'].rolling(24*7).mean().plot()
# Out:
# <AxesSubplot:xlabel='timestamp'>

# %% [markdown]
# Дифференцирование

# %%
plt.rc('figure',figsize=(12,3))
plt.rc('font',size=15)

data.value.diff(1).plot(); plt.show()
data.value.diff(24).diff(1).plot(); plt.show()

# %% [markdown]
# Простое разложение

# %%
from statsmodels.tsa.seasonal import seasonal_decompose
plt.rc('figure',figsize=(12,8))
plt.rc('font',size=15)

result = seasonal_decompose(data.value,model='additive')
fig = result.plot()

# %% [markdown]
# сравнение (остаток, метрика) от предсказания простой моделью

# %%
from statsmodels.tsa.api import ExponentialSmoothing, SimpleExpSmoothing, Holt
forecaster = ExponentialSmoothing(y,seasonal_periods=48,trend="add",seasonal="add").fit()
predicts = forecaster.predict(start=0, end=len(y)-1)

plt.rc('figure',figsize=(12,6))
plt.plot(data.index, y.reshape(-1) - predicts)
# Out:
# c:\users\ronkin\appdata\local\programs\python\python37\lib\site-packages\statsmodels\tsa\holtwinters\model.py:917: ConvergenceWarning: Optimization failed to converge. Check mle_retvals.
#   ConvergenceWarning,

# %% [markdown]
# Более тонкие разложения, например по т.н. внутренним модам

# %%
import dsatools 
y_dec = dsatools.decomposition.vmd(y.reshape(-1)[:], order =4)
plt.plot(data.index[1:-1],y_dec[0,1:-1])

y_dec = dsatools.decomposition.vmd(y.reshape(-1)[:], order =2)
plt.plot(data.index[1:-1],y_dec[0,1:-1])

# %%
y_dec = dsatools.decomposition.emd(y.reshape(-1)[:], order =10)
plt.plot(data.index[1:-1],y_dec[0,1:-1]); plt.show()

# %%
y_dec = dsatools.decomposition.hvd(y.reshape(-1)[:], order =2)
plt.plot(data.index[1:-1],y_dec[0,1:-1]); plt.show()

# %% [markdown]
# Ряд может быть обработан на основе четких правил

# %%
from adtk.detector import QuantileAD
from adtk.visualization import plot
quantile_ad = QuantileAD(high=0.99, low=0.01)
anomalies = quantile_ad.fit_detect(data)
plot(data, anomaly=anomalies, anomaly_color='red');

# %%
from adtk.detector import ThresholdAD
threshold_val = ThresholdAD(high=27000, low=1000)
anomalies_thresh = threshold_val.detect(data.value)
anomalies_thresh.value_counts()
plot(data, anomaly=anomalies_thresh, ts_linewidth=1, ts_markersize=3, anomaly_markersize=5, anomaly_color='black');

# %%
from adtk.detector import VolatilityShiftAD
volatility_shift_ad = VolatilityShiftAD(c=1.0, side='positive', window=30)
anomalies = volatility_shift_ad.fit_detect(data)
plot(data, anomaly=anomalies, anomaly_color='red');

# %%
from adtk.detector import LevelShiftAD
level_shift_ad = LevelShiftAD(c=0.2, side='both', window=50)
anomalies = level_shift_ad.fit_detect(data)
plot(data, anomaly=anomalies, anomaly_color='red');

# %%
from adtk.detector import SeasonalAD
seasonal_vol = SeasonalAD()
anomalies = seasonal_vol.fit_detect(data.value)
anomalies.value_counts()

plot(data, anomaly=anomalies, anomaly_color="orange", anomaly_tag="marker");

# %%
from adtk.detector import InterQuartileRangeAD
iqr_ad = InterQuartileRangeAD(c=0.9)
anomalies = iqr_ad.fit_detect(data)
plot(data, anomaly=anomalies, anomaly_color='red');

# %% [markdown]
# Также могут быть использованы специализированные алгоритмы

# %%
from sklearn.ensemble import IsolationForest

outliers_fraction = 0.007

model =  IsolationForest(contamination=outliers_fraction)
model.fit(data.value.values.reshape(-1, 1))

data['anomaly_IF'] = model.predict(y)

# visualization
fig, ax = plt.subplots(figsize=(10,6))

a = data.loc[data['anomaly_IF'] == -1, ['value']] #anomaly

ax.plot(data.index, data['value'], color='black', label = 'Normal')
ax.scatter(a.index,a['value'], color='red', label = 'Anomaly')
plt.legend()
plt.show();

# %%
from sklearn.neighbors import LocalOutlierFactor

lof = LocalOutlierFactor(novelty=True)

lof.fit(y)

data['anomaly_LOF'] = lof.predict()


fig, ax = plt.subplots(figsize=(10,6))

a = data.loc[data['anomaly_LOF'] == -1, ['value']] #anomaly

ax.plot(data.index, data['value'], color='black', label = 'Normal')
ax.scatter(a.index,a['value'], color='red', label = 'Anomaly')
plt.legend()
plt.show();

# %%
from sklearn.cluster import DBSCAN, KMeans
model=DBSCAN(eps = 100.)
# model = KMeans(n_clusters=10)

model.fit(y)
colors = model.labels_
cls,counts = np.unique(colors, return_counts=True)
sort_idx = np.argsort(counts)#[::-1]
print(counts[sort_idx], cls[sort_idx])
plt.scatter(data.index, y, c = colors == cls[sort_idx][-1])
# Out:
# [   7    9   14 5130] [ 2  1 -1  0]

# %% [markdown]
# По мимо sklearn есть и другие библиотеки работы с аномалиями, например https://pyod.readthedocs.io/en/latest/

# %%
import pyod.models
from pyod.models.gmm import GMM

clf = GMM( n_components=2, )
clf.fit(y)
y_scores = clf.decision_scores_
plt.plot(y_scores)

# %%
from pyod.models.ocsvm import OCSVM
pyod.models.anogan.AnoGAN
clf = OCSVM(kernel='poly',degree=3)
clf.fit(y)
y_scores = clf.decision_scores_
plt.plot(y_scores)

# %%
from pyod.models.hbos import HBOS

clf = HBOS(n_bins=100, alpha=0.1, tol=0.5, contamination=0.1)
clf.fit(y)
y_scores = clf.decision_scores_
plt.plot(y_scores)

# %% [markdown]
# в данной библиотеки pyod можно в т.ч. реализовать попробовать на основе восстановления автоэнокдером

# %%
import numpy as np
import pandas as pd
from pyod.models.auto_encoder import AutoEncoder

clf = AutoEncoder(hidden_neurons =[1,125, 125, 1])
clf.fit(y)
y_scores = clf.decision_scores_
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_21 (Dense)            (None, 1)                 2
#
#  dropout_18 (Dropout)        (None, 1)                 0
#
#  dense_22 (Dense)            (None, 1)                 2
#
#  dropout_19 (Dropout)        (None, 1)                 0
#
#  dense_23 (Dense)            (None, 1)                 2
#
#  dropout_20 (Dropout)        (None, 1)                 0
#
#  dense_24 (Dense)            (None, 125)               250
#
#  dropout_21 (Dropout)        (None, 125)               0
#
#  dense_25 (Dense)            (None, 125)               15750
#
#  dropout_22 (Dropout)        (None, 125)               0
#
#  dense_26 (Dense)            (None, 1)                 126
#
#  dropout_23 (Dropout)        (None, 1)                 0
#
#  dense_27 (Dense)            (None, 1)                 2
#
# =================================================================
# Total params: 16,134
# Trainable params: 16,134
# Non-trainable params: 0
# _________________________________________________________________
# None
# Epoch 1/100
# 146/146 [==============================] - 1s 3ms/step - loss: 1.2848 - val_loss: 1.3365
# Epoch 2/100
# 146/146 [==============================] - 0s 2ms/step - loss: 1.2352 - val_loss: 1.2905
# Epoch 3/100
# 146/146 [==============================] - 0s 2ms/step - loss: 1.1967 - val_loss: 1.2538
# Epoch 4/100
# 146/146 [==============================] - 0s 2ms/step - loss: 1.1661 - val_loss: 1.2241
# Epoch 5/100
# 146/146 [==============================] - 0s 2ms/step - loss: 1.1412 - val_loss: 1.1996
# Epoch 6/100
# 146/146 [==============================] - 0s 2ms/step - loss: 1.1208 - val_loss: 1.1788
# Epoch 7/100
# 146/146 [==============================] - 0s 3ms/step - loss: 1.1041 - val_loss: 1.1617
# Epoch 8/100
# 146/146 [==============================] - 0s 3ms/step - loss: 1.0901 - val_loss: 1.1472
# Epoch 9/100
# 146/146 [==============================] - 0s 3ms/step - loss: 1.0782 - val_loss: 1.1346
# Epoch 10/100
# 146/146 [==============================] - 0s 2ms/step - loss: 1.0682 - val_loss: 1.1241
# Epoch 11/100
# 146/146 [==============================] - 0s 3ms/step - loss: 1.0597 - val_loss: 1.1146
# Epoch 12/100
# 146/146 [==============================] - 0s 2ms/step - loss: 1.0523 - val_loss: 1.1066
# Epoch 13/100
# 146/146 [==============================] - 0s 2ms/step - loss: 1.0460 - val_loss: 1.0996
# Epoch 14/100
# 146/146 [==============================] - 0s 2ms/step - loss: 1.0406 - val_loss: 1.0935
# Epoch 15/100
# 146/146 [==============================] - 0s 2ms/step - loss: 1.0359 - val_loss: 1.0882
# Epoch 16/100
# 146/146 [==============================] - 0s 2ms/step - loss: 1.0319 - val_loss: 1.0836
# Epoch 17/100
# 146/146 [==============================] - 0s 2ms/step - loss: 1.0284 - val_loss: 1.0795
# Epoch 18/100
# 146/146 [==============================] - 0s 2ms/step - loss: 1.0252 - val_loss: 1.0758
# Epoch 19/100
# 146/146 [==============================] - 0s 2ms/step - loss: 1.0225 - val_loss: 1.0725
# Epoch 20/100
# 146/146 [==============================] - 0s 2ms/step - loss: 1.0200 - val_loss: 1.0695
# Epoch 21/100
# 146/146 [==============================] - 0s 2ms/step - loss: 1.0179 - val_loss: 1.0669
# Epoch 22/100
# 146/146 [==============================] - 0s 2ms/step - loss: 1.0160 - val_loss: 1.0645
# Epoch 23/100
# 146/146 [==============================] - 0s 2ms/step - loss: 1.0143 - val_loss: 1.0624
# Epoch 24/100
# 146/146 [==============================] - 0s 2ms/step - loss: 1.0128 - val_loss: 1.0604
# Epoch 25/100
# 146/146 [==============================] - 0s 2ms/step - loss: 1.0114 - val_loss: 1.0587
# Epoch 26/100
# 146/146 [==============================] - 0s 2ms/step - loss: 1.0101 - val_loss: 1.0571
# Epoch 27/100
# 146/146 [==============================] - 0s 2ms/step - loss: 1.0090 - val_loss: 1.0556
# Epoch 28/100
# 146/146 [==============================] - 0s 2ms/step - loss: 1.0080 - val_loss: 1.0542
# Epoch 29/100
# 146/146 [==============================] - 0s 2ms/step - loss: 1.0071 - val_loss: 1.0530
# Epoch 30/100
# 146/146 [==============================] - 0s 2ms/step - loss: 1.0063 - val_loss: 1.0518
# Epoch 31/100
# 146/146 [==============================] - 0s 2ms/step - loss: 1.0055 - val_loss: 1.0508
# Epoch 32/100
# 146/146 [==============================] - 0s 2ms/step - loss: 1.0049 - val_loss: 1.0498
# Epoch 33/100
# 146/146 [==============================] - 0s 2ms/step - loss: 1.0043 - val_loss: 1.0490
# Epoch 34/100
# 146/146 [==============================] - 0s 2ms/step - loss: 1.0037 - val_loss: 1.0481
# Epoch 35/100
# 146/146 [==============================] - 0s 2ms/step - loss: 1.0031 - val_loss: 1.0474
# Epoch 36/100
# 146/146 [==============================] - 0s 2ms/step - loss: 1.0027 - val_loss: 1.0466
# Epoch 37/100
# 146/146 [==============================] - 0s 2ms/step - loss: 1.0022 - val_loss: 1.0460
# Epoch 38/100
# 146/146 [==============================] - 0s 2ms/step - loss: 1.0018 - val_loss: 1.0454
# Epoch 39/100
# 146/146 [==============================] - 0s 2ms/step - loss: 1.0015 - val_loss: 1.0448
# Epoch 40/100
# 146/146 [==============================] - 0s 2ms/step - loss: 1.0011 - val_loss: 1.0443
# Epoch 41/100
# 146/146 [==============================] - 0s 2ms/step - loss: 1.0008 - val_loss: 1.0438
# Epoch 42/100
# 146/146 [==============================] - 0s 2ms/step - loss: 1.0006 - val_loss: 1.0433
# Epoch 43/100
# 146/146 [==============================] - 0s 2ms/step - loss: 1.0003 - val_loss: 1.0429
# Epoch 44/100
# 146/146 [==============================] - 0s 2ms/step - loss: 1.0000 - val_loss: 1.0425
# Epoch 45/100
# 146/146 [==============================] - 0s 3ms/step - loss: 0.9998 - val_loss: 1.0421
# Epoch 46/100
# 146/146 [==============================] - 0s 2ms/step - loss: 0.9996 - val_loss: 1.0418
# Epoch 47/100
# 146/146 [==============================] - 0s 2ms/step - loss: 0.9994 - val_loss: 1.0414
# Epoch 48/100
# 146/146 [==============================] - 0s 2ms/step - loss: 0.9992 - val_loss: 1.0411
# Epoch 49/100
# 146/146 [==============================] - 0s 2ms/step - loss: 0.9990 - val_loss: 1.0408
# Epoch 50/100
# 146/146 [==============================] - 0s 2ms/step - loss: 0.9989 - val_loss: 1.0405
# Epoch 51/100
# 146/146 [==============================] - 0s 2ms/step - loss: 0.9987 - val_loss: 1.0402
# Epoch 52/100
# 146/146 [==============================] - 0s 2ms/step - loss: 0.9986 - val_loss: 1.0399
# Epoch 53/100
# 146/146 [==============================] - 0s 2ms/step - loss: 0.9985 - val_loss: 1.0397
# Epoch 54/100
# 146/146 [==============================] - 0s 2ms/step - loss: 0.9984 - val_loss: 1.0395
# Epoch 55/100
# 146/146 [==============================] - 0s 2ms/step - loss: 0.9982 - val_loss: 1.0393
# Epoch 56/100
# 146/146 [==============================] - 0s 2ms/step - loss: 0.9981 - val_loss: 1.0391
# Epoch 57/100
# 146/146 [==============================] - 0s 2ms/step - loss: 0.9980 - val_loss: 1.0389
# Epoch 58/100
# 146/146 [==============================] - 0s 2ms/step - loss: 0.9979 - val_loss: 1.0387
# Epoch 59/100
# 146/146 [==============================] - 0s 2ms/step - loss: 0.9979 - val_loss: 1.0385
# Epoch 60/100
# 146/146 [==============================] - 0s 2ms/step - loss: 0.9978 - val_loss: 1.0384
# Epoch 61/100
# 146/146 [==============================] - 0s 2ms/step - loss: 0.9977 - val_loss: 1.0382
# Epoch 62/100
# 146/146 [==============================] - 0s 2ms/step - loss: 0.9976 - val_loss: 1.0380
# Epoch 63/100
# 146/146 [==============================] - 0s 2ms/step - loss: 0.9976 - val_loss: 1.0379
# Epoch 64/100
# 146/146 [==============================] - 0s 2ms/step - loss: 0.9975 - val_loss: 1.0378
# Epoch 65/100
# 146/146 [==============================] - 0s 2ms/step - loss: 0.9975 - val_loss: 1.0376
# Epoch 66/100
# 146/146 [==============================] - 0s 2ms/step - loss: 0.9974 - val_loss: 1.0375
# Epoch 67/100
# 146/146 [==============================] - 0s 2ms/step - loss: 0.9973 - val_loss: 1.0374
# Epoch 68/100
# 146/146 [==============================] - 0s 2ms/step - loss: 0.9973 - val_loss: 1.0373
# Epoch 69/100
# 146/146 [==============================] - 0s 2ms/step - loss: 0.9973 - val_loss: 1.0372
# Epoch 70/100
# 146/146 [==============================] - 0s 2ms/step - loss: 0.9972 - val_loss: 1.0371
# Epoch 71/100
# 146/146 [==============================] - 0s 2ms/step - loss: 0.9972 - val_loss: 1.0370
# Epoch 72/100
# 146/146 [==============================] - 0s 2ms/step - loss: 0.9971 - val_loss: 1.0369
# Epoch 73/100
# 146/146 [==============================] - 0s 2ms/step - loss: 0.9971 - val_loss: 1.0368
# Epoch 74/100
# 146/146 [==============================] - 0s 2ms/step - loss: 0.9971 - val_loss: 1.0367
# Epoch 75/100
# 146/146 [==============================] - 0s 2ms/step - loss: 0.9970 - val_loss: 1.0366
# Epoch 76/100
# 146/146 [==============================] - 0s 2ms/step - loss: 0.9970 - val_loss: 1.0366
# Epoch 77/100
# 146/146 [==============================] - 0s 2ms/step - loss: 0.9970 - val_loss: 1.0365
# Epoch 78/100
# 146/146 [==============================] - 0s 2ms/step - loss: 0.9969 - val_loss: 1.0364
# Epoch 79/100
# 146/146 [==============================] - 0s 2ms/step - loss: 0.9969 - val_loss: 1.0364
# Epoch 80/100
# 146/146 [==============================] - 0s 2ms/step - loss: 0.9969 - val_loss: 1.0363
# Epoch 81/100
# 146/146 [==============================] - 0s 2ms/step - loss: 0.9969 - val_loss: 1.0362
# Epoch 82/100
# 146/146 [==============================] - 0s 2ms/step - loss: 0.9968 - val_loss: 1.0361
# Epoch 83/100
# 146/146 [==============================] - 0s 2ms/step - loss: 0.9968 - val_loss: 1.0361
# Epoch 84/100
# 146/146 [==============================] - 0s 2ms/step - loss: 0.9968 - val_loss: 1.0360
# Epoch 85/100
# 146/146 [==============================] - 0s 2ms/step - loss: 0.9968 - val_loss: 1.0360
# Epoch 86/100
# 146/146 [==============================] - 0s 2ms/step - loss: 0.9968 - val_loss: 1.0359
# Epoch 87/100
# 146/146 [==============================] - 0s 2ms/step - loss: 0.9968 - val_loss: 1.0359
# Epoch 88/100
# 146/146 [==============================] - 0s 2ms/step - loss: 0.9967 - val_loss: 1.0358
# Epoch 89/100
# 146/146 [==============================] - 0s 2ms/step - loss: 0.9967 - val_loss: 1.0358
# Epoch 90/100
# 146/146 [==============================] - 0s 3ms/step - loss: 0.9967 - val_loss: 1.0357
# Epoch 91/100
# 146/146 [==============================] - 0s 2ms/step - loss: 0.9967 - val_loss: 1.0357
# Epoch 92/100
# 146/146 [==============================] - 1s 4ms/step - loss: 0.9967 - val_loss: 1.0357
# Epoch 93/100
# 146/146 [==============================] - 0s 2ms/step - loss: 0.9967 - val_loss: 1.0356
# Epoch 94/100
# 146/146 [==============================] - 0s 2ms/step - loss: 0.9967 - val_loss: 1.0356
# Epoch 95/100
# 146/146 [==============================] - 0s 2ms/step - loss: 0.9967 - val_loss: 1.0355
# Epoch 96/100
# 146/146 [==============================] - 0s 2ms/step - loss: 0.9966 - val_loss: 1.0355
# Epoch 97/100
# 146/146 [==============================] - 0s 3ms/step - loss: 0.9966 - val_loss: 1.0354
# Epoch 98/100
# 146/146 [==============================] - 0s 3ms/step - loss: 0.9966 - val_loss: 1.0354
# Epoch 99/100
# 146/146 [==============================] - 0s 2ms/step - loss: 0.9966 - val_loss: 1.0354
# Epoch 100/100
# 146/146 [==============================] - 0s 3ms/step - loss: 0.9966 - val_loss: 1.0353
# 162/162 [==============================] - 0s 1ms/step

# %%
plt.plot(data.index,y_scores); plt.show()

# %% [markdown]
# https://www.kaggle.com/code/joshuaswords/time-series-anomaly-detection

# %% [markdown]
# https://github.com/rob-med/awesome-TS-anomaly-detection

# %% [markdown]
# https://github.com/yzhao062/anomaly-detection-resources
