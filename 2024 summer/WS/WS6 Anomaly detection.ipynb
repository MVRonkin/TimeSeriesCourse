# %%
import numpy as np
import pandas as pd

import matplotlib.pyplot as plt
from datetime import datetime
import seaborn as sns
sns.set(style="whitegrid")

import warnings
warnings.filterwarnings('ignore')

RANDOM_SEED = np.random.seed(0)

# %%
try:
    import dsatools
except:
    # !pip install dsatools
finally:
    import dsatools
    
    
try:
    import adtk
except:
    # !pip install adtk
finally:
    import adtk
# Out:
# Collecting adtk
#   Using cached adtk-0.6.2-py3-none-any.whl (60 kB)
# Requirement already satisfied: numpy>=1.15 in c:\users\ronkin\anaconda3\lib\site-packages (from adtk) (1.24.3)
# Requirement already satisfied: pandas>=0.23 in c:\users\ronkin\anaconda3\lib\site-packages (from adtk) (2.0.3)
# Requirement already satisfied: matplotlib>=3.0 in c:\users\ronkin\anaconda3\lib\site-packages (from adtk) (3.7.2)
# Requirement already satisfied: scikit-learn>=0.20 in c:\users\ronkin\anaconda3\lib\site-packages (from adtk) (1.3.0)
# Requirement already satisfied: statsmodels>=0.9 in c:\users\ronkin\anaconda3\lib\site-packages (from adtk) (0.14.0)
# Requirement already satisfied: packaging>=17.0 in c:\users\ronkin\anaconda3\lib\site-packages (from adtk) (23.1)
# Requirement already satisfied: tabulate>=0.8 in c:\users\ronkin\anaconda3\lib\site-packages (from adtk) (0.8.10)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\ronkin\anaconda3\lib\site-packages (from matplotlib>=3.0->adtk) (1.0.5)
# Requirement already satisfied: cycler>=0.10 in c:\users\ronkin\anaconda3\lib\site-packages (from matplotlib>=3.0->adtk) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\ronkin\anaconda3\lib\site-packages (from matplotlib>=3.0->adtk) (4.25.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\ronkin\anaconda3\lib\site-packages (from matplotlib>=3.0->adtk) (1.4.4)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\ronkin\anaconda3\lib\site-packages (from matplotlib>=3.0->adtk) (10.0.1)
# Requirement already satisfied: pyparsing<3.1,>=2.3.1 in c:\users\ronkin\anaconda3\lib\site-packages (from matplotlib>=3.0->adtk) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\ronkin\anaconda3\lib\site-packages (from matplotlib>=3.0->adtk) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\ronkin\anaconda3\lib\site-packages (from pandas>=0.23->adtk) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.1 in c:\users\ronkin\anaconda3\lib\site-packages (from pandas>=0.23->adtk) (2023.3)
# Requirement already satisfied: scipy>=1.5.0 in c:\users\ronkin\anaconda3\lib\site-packages (from scikit-learn>=0.20->adtk) (1.11.1)
# Requirement already satisfied: joblib>=1.1.1 in c:\users\ronkin\anaconda3\lib\site-packages (from scikit-learn>=0.20->adtk) (1.2.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\ronkin\anaconda3\lib\site-packages (from scikit-learn>=0.20->adtk) (2.2.0)
# Requirement already satisfied: patsy>=0.5.2 in c:\users\ronkin\anaconda3\lib\site-packages (from statsmodels>=0.9->adtk) (0.5.3)
# Requirement already satisfied: six in c:\users\ronkin\anaconda3\lib\site-packages (from patsy>=0.5.2->statsmodels>=0.9->adtk) (1.16.0)
# Installing collected packages: adtk
# Successfully installed adtk-0.6.2

# %% [markdown]
# Данные: набор востребованности такси в городе Нью Йорк с шагом в 1 час.

# %%
import pandas as pd
data = pd.read_csv('https://raw.githubusercontent.com/numenta/NAB/master/data/realKnownCause/nyc_taxi.csv')
data['timestamp'] = pd.to_datetime(data['timestamp'])
data = data.set_index(['timestamp']).asfreq('h')
data.head()
# Out:
#                      value
# timestamp
# 2014-07-01 00:00:00  10844
# 2014-07-01 01:00:00   6210
# 2014-07-01 02:00:00   3820
# 2014-07-01 03:00:00   2369
# 2014-07-01 04:00:00   2221

# %%
y = data.value.values.reshape(-1, 1)

# %%
plt.plot(data.index, y)

# %% [markdown]
# Данные во временных рядах можно рассматривать как в чистом виде, так и преобразовать.
#
# Попробуем скользящее средние и скользящие СКО

# %%
plt.rc('figure',figsize=(12,6))
plt.rc('font',size=15)
# create moving-averages
data['value'].rolling(24).mean().plot()
data['value'].rolling(24).std().plot()
data['value'].rolling(24*7).mean().plot()
# Out:
# <Axes: xlabel='timestamp'>

# %% [markdown]
# Дифференцирование

# %%
plt.rc('figure',figsize=(12,3))
plt.rc('font',size=15)

data.value.diff(1).plot(); plt.show()
data.value.diff(24).diff(1).plot(); plt.show()

# %% [markdown]
# Простое разложение

# %%
from statsmodels.tsa.seasonal import seasonal_decompose
plt.rc('figure',figsize=(12,8))
plt.rc('font',size=15)

result = seasonal_decompose(data.value,model='additive')
fig = result.plot()

# %% [markdown]
# сравнение (остаток, метрика) от предсказания простой моделью

# %%
from statsmodels.tsa.api import ExponentialSmoothing, SimpleExpSmoothing, Holt
forecaster = ExponentialSmoothing(y,seasonal_periods=48,trend="add",seasonal="add").fit()
predicts = forecaster.predict(start=0, end=len(y)-1)

plt.rc('figure',figsize=(12,6))
plt.plot(data.index, y.reshape(-1) - predicts)
# Out:
# C:\Users\Ronkin\anaconda3\Lib\site-packages\statsmodels\tsa\holtwinters\model.py:917: ConvergenceWarning: Optimization failed to converge. Check mle_retvals.
#   warnings.warn(

# %% [markdown]
# Более тонкие разложения, например по т.н. внутренним модам

# %%
# import dsatools 
# y_dec = dsatools.decomposition.vmd(y.reshape(-1)[:], order =4)
# plt.plot(data.index[1:-1],y_dec[0,1:-1])

# y_dec = dsatools.decomposition.vmd(y.reshape(-1)[:], order =2)
# plt.plot(data.index[1:-1],y_dec[0,1:-1])

# %%
y_dec = dsatools.decomposition.emd(y.reshape(-1)[:], order =10)
plt.plot(data.index[1:-1],y_dec[0,1:-1]); plt.show()

# %%
y_dec = dsatools.decomposition.hvd(y.reshape(-1)[:], order =2)
plt.plot(data.index[1:-1],y_dec[0,1:-1]); plt.show()

# %% [markdown]
# Ряд может быть обработан на основе четких правил

# %%
from adtk.detector import QuantileAD
from adtk.visualization import plot
quantile_ad = QuantileAD(high=0.99, low=0.01)
anomalies = quantile_ad.fit_detect(data)
plot(data, anomaly=anomalies, anomaly_color="orange", anomaly_tag="marker");

# %%
from adtk.detector import ThresholdAD
threshold_val = ThresholdAD(high=27000, low=1000)
anomalies_thresh = threshold_val.detect(data.value)
anomalies_thresh.value_counts()
plot(data, anomaly=anomalies, anomaly_color="orange", anomaly_tag="marker");

# %%
from adtk.detector import VolatilityShiftAD
volatility_shift_ad = VolatilityShiftAD(c=1.0, side='positive', window=30)
anomalies = volatility_shift_ad.fit_detect(data)
plot(data, anomaly=anomalies, anomaly_color="orange", anomaly_tag="marker");

# %%
from adtk.detector import LevelShiftAD
level_shift_ad = LevelShiftAD(c=0.2, side='both', window=50)
anomalies = level_shift_ad.fit_detect(data)
plot(data, anomaly=anomalies, anomaly_color="orange", anomaly_tag="marker");

# %%
from adtk.detector import SeasonalAD
seasonal_vol = SeasonalAD()
anomalies = seasonal_vol.fit_detect(data.value)
anomalies.value_counts()

plot(data, anomaly=anomalies, anomaly_color="orange", anomaly_tag="marker");

# %%
from adtk.detector import InterQuartileRangeAD
iqr_ad = InterQuartileRangeAD(c=0.9)
anomalies = iqr_ad.fit_detect(data)
anomalies = anomalies.squeeze()
plot(data, anomaly=anomalies, anomaly_color="orange", anomaly_tag="marker");

# %% [markdown]
# Также могут быть использованы специализированные алгоритмы

# %%
from sklearn.ensemble import IsolationForest

outliers_fraction = 0.007

model =  IsolationForest(contamination=outliers_fraction)
model.fit(data.value.values.reshape(-1, 1))

data['anomaly_IF'] = model.predict(y)

# visualization
fig, ax = plt.subplots(figsize=(10,6))

a = data.loc[data['anomaly_IF'] == -1, ['value']] #anomaly

ax.plot(data.index, data['value'], color='black', label = 'Normal')
ax.scatter(a.index,a['value'], color='red', label = 'Anomaly')
plt.legend()
plt.show();

# %%
from sklearn.neighbors import LocalOutlierFactor

lof = LocalOutlierFactor(novelty=True)

lof.fit(y)

data['anomaly_LOF'] = lof.predict()


fig, ax = plt.subplots(figsize=(10,6))

a = data.loc[data['anomaly_LOF'] == -1, ['value']] #anomaly

ax.plot(data.index, data['value'], color='black', label = 'Normal')
ax.scatter(a.index,a['value'], color='red', label = 'Anomaly')
plt.legend()
plt.show();

# %%
from sklearn.cluster import DBSCAN, KMeans
model=DBSCAN(eps = 100.)
# model = KMeans(n_clusters=10)

model.fit(y)
colors = model.labels_
cls,counts = np.unique(colors, return_counts=True)
sort_idx = np.argsort(counts)#[::-1]
print(counts[sort_idx], cls[sort_idx])
plt.scatter(data.index, y, c = colors == cls[sort_idx][-1])
# Out:
# [   7    9   14 5130] [ 2  1 -1  0]

# %% [markdown]
# По мимо sklearn есть и другие библиотеки работы с аномалиями, например https://pyod.readthedocs.io/en/latest/

# %%
import pyod.models
from pyod.models.gmm import GMM

clf = GMM( n_components=2, )
clf.fit(y)
y_scores = clf.decision_scores_
plt.plot(y_scores)

# %%
from pyod.models.ocsvm import OCSVM
# pyod.models.anogan.AnoGAN
clf = OCSVM(kernel='poly',degree=3)
clf.fit(y)
y_scores = clf.decision_scores_
plt.plot(y_scores)

# %%
from pyod.models.hbos import HBOS

clf = HBOS(n_bins=100, alpha=0.1, tol=0.5, contamination=0.1)
clf.fit(y)
y_scores = clf.decision_scores_
plt.plot(y_scores)

# %% [markdown]
# в данной библиотеки pyod можно в т.ч. реализовать попробовать на основе восстановления автоэнокдером

# %%
import numpy as np
import pandas as pd
from pyod.models.auto_encoder import AutoEncoder

clf = AutoEncoder(hidden_neurons =[1,125, 125, 1])
clf.fit(y)
y_scores = clf.decision_scores_
# Out:
# WARNING:tensorflow:From C:\Users\Ronkin\anaconda3\Lib\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.
#
# WARNING:tensorflow:From C:\Users\Ronkin\anaconda3\Lib\site-packages\keras\src\backend.py:873: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# WARNING:tensorflow:From C:\Users\Ronkin\anaconda3\Lib\site-packages\keras\src\engine\base_layer_utils.py:384: The name tf.executing_eagerly_outside_functions is deprecated. Please use tf.compat.v1.executing_eagerly_outside_functions instead.
#
# WARNING:tensorflow:From C:\Users\Ronkin\anaconda3\Lib\site-packages\keras\src\optimizers\__init__.py:309: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.
#
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 1)                 2
#
#  dropout (Dropout)           (None, 1)                 0
#
#  dense_1 (Dense)             (None, 1)                 2
#
#  dropout_1 (Dropout)         (None, 1)                 0
#
#  dense_2 (Dense)             (None, 1)                 2
#
#  dropout_2 (Dropout)         (None, 1)                 0
#
#  dense_3 (Dense)             (None, 125)               250
#
#  dropout_3 (Dropout)         (None, 125)               0
#
#  dense_4 (Dense)             (None, 125)               15750
#
#  dropout_4 (Dropout)         (None, 125)               0
#
#  dense_5 (Dense)             (None, 1)                 126
#
#  dropout_5 (Dropout)         (None, 1)                 0
#
#  dense_6 (Dense)             (None, 1)                 2
#
# =================================================================
# Total params: 16134 (63.02 KB)
# Trainable params: 16134 (63.02 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# None
# Epoch 1/100
# WARNING:tensorflow:From C:\Users\Ronkin\anaconda3\Lib\site-packages\keras\src\utils\tf_utils.py:492: The name tf.ragged.RaggedTensorValue is deprecated. Please use tf.compat.v1.ragged.RaggedTensorValue instead.
#
# 146/146 [==============================] - 3s 5ms/step - loss: 1.3809 - val_loss: 1.3627
# Epoch 2/100
# 146/146 [==============================] - 0s 3ms/step - loss: 1.2427 - val_loss: 1.2841
# Epoch 3/100
# 146/146 [==============================] - 0s 3ms/step - loss: 1.1819 - val_loss: 1.2270
# Epoch 4/100
# 146/146 [==============================] - 0s 3ms/step - loss: 1.1397 - val_loss: 1.1853
# Epoch 5/100
# 146/146 [==============================] - 0s 3ms/step - loss: 1.1092 - val_loss: 1.1542
# Epoch 6/100
# 146/146 [==============================] - 0s 3ms/step - loss: 1.0823 - val_loss: 1.1289
# Epoch 7/100
# 146/146 [==============================] - 0s 3ms/step - loss: 1.0639 - val_loss: 1.0932
# Epoch 8/100
# 146/146 [==============================] - 0s 3ms/step - loss: 1.0407 - val_loss: 1.0650
# Epoch 9/100
# 146/146 [==============================] - 0s 3ms/step - loss: 1.0303 - val_loss: 1.0418
# Epoch 10/100
# 146/146 [==============================] - 0s 3ms/step - loss: 1.0145 - val_loss: 1.0212
# Epoch 11/100
# 146/146 [==============================] - 0s 3ms/step - loss: 1.0017 - val_loss: 1.0010
# Epoch 12/100
# 146/146 [==============================] - 0s 3ms/step - loss: 0.9910 - val_loss: 0.9922
# Epoch 13/100
# 146/146 [==============================] - 0s 3ms/step - loss: 0.9815 - val_loss: 0.9677
# Epoch 14/100
# 146/146 [==============================] - 0s 3ms/step - loss: 0.9666 - val_loss: 0.9609
# Epoch 15/100
# 146/146 [==============================] - 0s 3ms/step - loss: 0.9639 - val_loss: 0.9649
# Epoch 16/100
# 146/146 [==============================] - 0s 3ms/step - loss: 0.9543 - val_loss: 0.9454
# Epoch 17/100
# 146/146 [==============================] - 0s 3ms/step - loss: 0.9366 - val_loss: 0.9347
# Epoch 18/100
# 146/146 [==============================] - 0s 3ms/step - loss: 0.9341 - val_loss: 0.9584
# Epoch 19/100
# 146/146 [==============================] - 0s 3ms/step - loss: 0.9293 - val_loss: 0.9489
# Epoch 20/100
# 146/146 [==============================] - 0s 3ms/step - loss: 0.9284 - val_loss: 0.9387
# Epoch 21/100
# 146/146 [==============================] - 0s 3ms/step - loss: 0.9188 - val_loss: 0.9322
# Epoch 22/100
# 146/146 [==============================] - 0s 3ms/step - loss: 0.9160 - val_loss: 0.9484
# Epoch 23/100
# 146/146 [==============================] - 0s 3ms/step - loss: 0.9116 - val_loss: 0.9322
# Epoch 24/100
# 146/146 [==============================] - 0s 3ms/step - loss: 0.9120 - val_loss: 0.9345
# Epoch 25/100
# 146/146 [==============================] - 0s 3ms/step - loss: 0.8997 - val_loss: 0.9338
# Epoch 26/100
# 146/146 [==============================] - 0s 3ms/step - loss: 0.9044 - val_loss: 0.9246
# Epoch 27/100
# 146/146 [==============================] - 0s 3ms/step - loss: 0.8944 - val_loss: 0.9216
# Epoch 28/100
# 146/146 [==============================] - 0s 3ms/step - loss: 0.8936 - val_loss: 0.9115
# Epoch 29/100
# 146/146 [==============================] - 0s 3ms/step - loss: 0.8998 - val_loss: 0.9190
# Epoch 30/100
# 146/146 [==============================] - 0s 3ms/step - loss: 0.8941 - val_loss: 0.9551
# Epoch 31/100
# 146/146 [==============================] - 0s 3ms/step - loss: 0.8917 - val_loss: 0.8675
# Epoch 32/100
# 146/146 [==============================] - 0s 3ms/step - loss: 0.8873 - val_loss: 0.9124
# Epoch 33/100
# 146/146 [==============================] - 0s 3ms/step - loss: 0.8899 - val_loss: 0.9284
# Epoch 34/100
# 146/146 [==============================] - 0s 3ms/step - loss: 0.8831 - val_loss: 0.9132
# Epoch 35/100
# 146/146 [==============================] - 0s 3ms/step - loss: 0.8899 - val_loss: 0.8917
# Epoch 36/100
# 146/146 [==============================] - 0s 3ms/step - loss: 0.8794 - val_loss: 0.9053
# Epoch 37/100
# 146/146 [==============================] - 0s 3ms/step - loss: 0.8842 - val_loss: 0.9316
# Epoch 38/100
# 146/146 [==============================] - 0s 3ms/step - loss: 0.8815 - val_loss: 0.9224
# Epoch 39/100
# 146/146 [==============================] - 0s 3ms/step - loss: 0.8821 - val_loss: 0.9158
# Epoch 40/100
# 146/146 [==============================] - 0s 3ms/step - loss: 0.8769 - val_loss: 0.9100
# Epoch 41/100
# 146/146 [==============================] - 0s 3ms/step - loss: 0.8704 - val_loss: 0.9064
# Epoch 42/100
# 146/146 [==============================] - 0s 3ms/step - loss: 0.8753 - val_loss: 0.9281
# Epoch 43/100
# 146/146 [==============================] - 0s 3ms/step - loss: 0.8735 - val_loss: 0.9311
# Epoch 44/100
# 146/146 [==============================] - 0s 3ms/step - loss: 0.8721 - val_loss: 0.9107
# Epoch 45/100
# 146/146 [==============================] - 0s 3ms/step - loss: 0.8715 - val_loss: 0.8868
# Epoch 46/100
# 146/146 [==============================] - 0s 3ms/step - loss: 0.8769 - val_loss: 0.9017
# Epoch 47/100
# 146/146 [==============================] - 0s 3ms/step - loss: 0.8716 - val_loss: 0.9132
# Epoch 48/100
# 146/146 [==============================] - 0s 3ms/step - loss: 0.8666 - val_loss: 0.8911
# Epoch 49/100
# 146/146 [==============================] - 0s 3ms/step - loss: 0.8775 - val_loss: 0.9355
# Epoch 50/100
# 146/146 [==============================] - 0s 3ms/step - loss: 0.8723 - val_loss: 0.9186
# Epoch 51/100
# 146/146 [==============================] - 0s 3ms/step - loss: 0.8735 - val_loss: 0.9064
# Epoch 52/100
# 146/146 [==============================] - 0s 3ms/step - loss: 0.8810 - val_loss: 0.9191
# Epoch 53/100
# 146/146 [==============================] - 0s 3ms/step - loss: 0.8694 - val_loss: 0.9333
# Epoch 54/100
# 146/146 [==============================] - 0s 3ms/step - loss: 0.8674 - val_loss: 0.9251
# Epoch 55/100
# 146/146 [==============================] - 0s 3ms/step - loss: 0.8664 - val_loss: 0.9098
# Epoch 56/100
# 146/146 [==============================] - 0s 3ms/step - loss: 0.8676 - val_loss: 0.8934
# Epoch 57/100
# 146/146 [==============================] - 0s 3ms/step - loss: 0.8647 - val_loss: 0.8837
# Epoch 58/100
# 146/146 [==============================] - 0s 3ms/step - loss: 0.8577 - val_loss: 0.8890
# Epoch 59/100
# 146/146 [==============================] - 0s 3ms/step - loss: 0.8617 - val_loss: 0.9183
# Epoch 60/100
# 146/146 [==============================] - 0s 3ms/step - loss: 0.8583 - val_loss: 0.8783
# Epoch 61/100
# 146/146 [==============================] - 0s 3ms/step - loss: 0.8664 - val_loss: 0.9047
# Epoch 62/100
# 146/146 [==============================] - 0s 3ms/step - loss: 0.8691 - val_loss: 0.9027
# Epoch 63/100
# 146/146 [==============================] - 0s 3ms/step - loss: 0.8629 - val_loss: 0.9057
# Epoch 64/100
# 146/146 [==============================] - 0s 3ms/step - loss: 0.8665 - val_loss: 0.9021
# Epoch 65/100
# 146/146 [==============================] - 0s 3ms/step - loss: 0.8722 - val_loss: 0.8997
# Epoch 66/100
# 146/146 [==============================] - 0s 3ms/step - loss: 0.8576 - val_loss: 0.8921
# Epoch 67/100
# 146/146 [==============================] - 0s 3ms/step - loss: 0.8552 - val_loss: 0.8766
# Epoch 68/100
# 146/146 [==============================] - 0s 3ms/step - loss: 0.8653 - val_loss: 0.9271
# Epoch 69/100
# 146/146 [==============================] - 0s 3ms/step - loss: 0.8606 - val_loss: 0.9163
# Epoch 70/100
# 146/146 [==============================] - 0s 3ms/step - loss: 0.8679 - val_loss: 0.9219
# Epoch 71/100
# 146/146 [==============================] - 0s 3ms/step - loss: 0.8582 - val_loss: 0.9212
# Epoch 72/100
# 146/146 [==============================] - 0s 3ms/step - loss: 0.8641 - val_loss: 0.8935
# Epoch 73/100
# 146/146 [==============================] - 0s 3ms/step - loss: 0.8612 - val_loss: 0.9117
# Epoch 74/100
# 146/146 [==============================] - 0s 3ms/step - loss: 0.8664 - val_loss: 0.9235
# Epoch 75/100
# 146/146 [==============================] - 0s 3ms/step - loss: 0.8571 - val_loss: 0.9403
# Epoch 76/100
# 146/146 [==============================] - 0s 3ms/step - loss: 0.8614 - val_loss: 0.9455
# Epoch 77/100
# 146/146 [==============================] - 0s 3ms/step - loss: 0.8569 - val_loss: 0.9193
# Epoch 78/100
# 146/146 [==============================] - 0s 3ms/step - loss: 0.8526 - val_loss: 0.9112
# Epoch 79/100
# 146/146 [==============================] - 0s 3ms/step - loss: 0.8649 - val_loss: 0.9022
# Epoch 80/100
# 146/146 [==============================] - 0s 3ms/step - loss: 0.8570 - val_loss: 0.9296
# Epoch 81/100
# 146/146 [==============================] - 0s 3ms/step - loss: 0.8627 - val_loss: 0.9032
# Epoch 82/100
# 146/146 [==============================] - 0s 3ms/step - loss: 0.8697 - val_loss: 0.9027
# Epoch 83/100
# 146/146 [==============================] - 0s 3ms/step - loss: 0.8594 - val_loss: 0.9233
# Epoch 84/100
# 146/146 [==============================] - 0s 3ms/step - loss: 0.8698 - val_loss: 0.8943
# Epoch 85/100
# 146/146 [==============================] - 0s 3ms/step - loss: 0.8583 - val_loss: 0.9159
# Epoch 86/100
# 146/146 [==============================] - 0s 3ms/step - loss: 0.8547 - val_loss: 0.9164
# Epoch 87/100
# 146/146 [==============================] - 0s 3ms/step - loss: 0.8617 - val_loss: 0.8962
# Epoch 88/100
# 146/146 [==============================] - 0s 3ms/step - loss: 0.8586 - val_loss: 0.9153
# Epoch 89/100
# 146/146 [==============================] - 0s 3ms/step - loss: 0.8593 - val_loss: 0.9161
# Epoch 90/100
# 146/146 [==============================] - 0s 3ms/step - loss: 0.8577 - val_loss: 0.9125
# Epoch 91/100
# 146/146 [==============================] - 0s 3ms/step - loss: 0.8582 - val_loss: 0.9223
# Epoch 92/100
# 146/146 [==============================] - 0s 3ms/step - loss: 0.8640 - val_loss: 0.9208
# Epoch 93/100
# 146/146 [==============================] - 0s 3ms/step - loss: 0.8542 - val_loss: 0.9325
# Epoch 94/100
# 146/146 [==============================] - 0s 3ms/step - loss: 0.8568 - val_loss: 0.9213
# Epoch 95/100
# 146/146 [==============================] - 0s 3ms/step - loss: 0.8601 - val_loss: 0.9325
# Epoch 96/100
# 146/146 [==============================] - 0s 3ms/step - loss: 0.8598 - val_loss: 0.9326
# Epoch 97/100
# 146/146 [==============================] - 0s 3ms/step - loss: 0.8569 - val_loss: 0.9283
# Epoch 98/100
# 146/146 [==============================] - 0s 3ms/step - loss: 0.8570 - val_loss: 0.9256
# Epoch 99/100
# 146/146 [==============================] - 0s 3ms/step - loss: 0.8625 - val_loss: 0.9207
# Epoch 100/100
# 146/146 [==============================] - 0s 3ms/step - loss: 0.8734 - val_loss: 0.9191
# 162/162 [==============================] - 0s 2ms/step

# %%
plt.plot(data.index,y_scores); plt.show()

# %% [markdown]
# https://www.kaggle.com/code/joshuaswords/time-series-anomaly-detection

# %% [markdown]
# https://github.com/rob-med/awesome-TS-anomaly-detection

# %% [markdown]
# https://github.com/yzhao062/anomaly-detection-resources
